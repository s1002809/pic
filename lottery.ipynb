# %%
import random

for i in range(0,100000):
    open_number = format(random.randint(0000,9999), '04d')
    player_number= format(random.randint(0000,9999), '04d')
    
    if open_number == player_number:
        print('you win')
    else:
        print("you lose")
# Out:
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# you lose
# ...

# %%
# Out:
# str
